# %% [markdown]
# y = bo  + bx1
#
# y is the target
# bo is the coeffiecient representing the y_intercept and slope of regression line

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

# calculate the slope and intercept 
m, b = np.polyfit(X, y, 1)

# predicted values 
y_pred = m * X + b
print(m, b, y_pred)
# Out:
# 0.6 2.199999999999999 [2.8 3.4 4.  4.6 5.2]

# %%
# plot the graph 
plt.scatter(X,y, color="blue", label="Actual Data")
plt.scatter(X,y_pred, color="red", label="Regression Data")
plt.legend()
plt.show()
